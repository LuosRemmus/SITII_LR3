# %%
import pandas as pd
from sklearn.cluster import MeanShift, AgglomerativeClustering, AffinityPropagation
from sklearn.metrics import silhouette_score

# %%
data = pd.read_parquet("data18.parquet")
data = data.drop(['protocol_type', 'service', 'flag', 'Label'], axis=1).astype('float64')

# %%
data.head()
# Out:
#         duration  src_bytes  dst_bytes  land  wrong_fragment  urgent  hot  \
# 84672        0.0      200.0      563.0   0.0             0.0     0.0  0.0
# 104569       0.0      167.0     1578.0   0.0             0.0     0.0  0.0
# 147646       0.0     2030.0      332.0   0.0             0.0     0.0  0.0
# 37376        0.0      339.0     2037.0   0.0             0.0     0.0  0.0
# 4166         0.0       44.0       69.0   0.0             0.0     0.0  0.0
#
#         num_failed_logins  logged_in  num_compromised  ...  dst_host_count  \
# 84672                 0.0        1.0              0.0  ...             8.0
# 104569                0.0        1.0              0.0  ...             2.0
# 147646                0.0        1.0              0.0  ...           144.0
# 37376                 0.0        1.0              0.0  ...            56.0
# 4166                  0.0        0.0              0.0  ...           255.0
#
#         dst_host_srv_count  dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 84672                255.0                    1.00                    0.00
# 104569               255.0                    1.00                    0.00
# 147646               170.0                    0.71                    0.05
# 37376                255.0                    1.00                    0.00
# 4166                 215.0                    0.84                    0.01
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 84672                          0.12                         0.03
# 104569                         0.50                         0.08
# 147646                         0.01                         0.01
# 37376                          0.02                         0.04
# 4166                           0.00                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 84672                    0.0                      0.02                   0.0
# 104569                   0.0                      0.00                   0.0
# 147646                   0.0                      0.00                   0.0
# 37376                    0.0                      0.00                   0.0
# 4166                     0.0                      0.00                   0.0
#
#         dst_host_srv_rerror_rate
# 84672                        0.0
# 104569                       0.0
# 147646                       0.0
# 37376                        0.0
# 4166                         0.0
#
# [5 rows x 38 columns]

# %%
# Обучение модели MeanShift
meanshift = MeanShift()
meanshift_clusters = meanshift.fit_predict(data)
print("MeanShift Silhouette Score:", silhouette_score(data, meanshift_clusters))

# Обучение модели AgglomerativeClustering
agglomerative = AgglomerativeClustering(n_clusters=3)
agglomerative_clusters = agglomerative.fit_predict(data)
print("Agglomerative Clustering Silhouette Score:", silhouette_score(data, agglomerative_clusters))

# Обучение модели AffinityPropagation
affinity_propagation = AffinityPropagation()
affinity_clusters = affinity_propagation.fit_predict(data)
print("Affinity Propagation Silhouette Score:", silhouette_score(data, affinity_clusters))
# Out:
# c:\Users\HonorPC\Desktop\Study\СИТИИ\LR3\venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\HonorPC\Desktop\Study\СИТИИ\LR3\venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# MeanShift Silhouette Score: 0.9395379175170917
# Agglomerative Clustering Silhouette Score: 0.9601793793402973
# c:\Users\HonorPC\Desktop\Study\СИТИИ\LR3\venv\Lib\site-packages\sklearn\cluster\_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# Affinity Propagation Silhouette Score: 0.3057985584850864
